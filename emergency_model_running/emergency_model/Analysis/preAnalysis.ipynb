# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 1500)

#Fire 42 subtypes
#Law 36

# %%
df = pd.read_csv("./../dataprocess/Emergency_Response_Incidents.csv", error_bad_lines=False, index_col=False) #9018

# %%
clasify = 'Incident Type'
EMOriginalRT = df[(df[clasify].str.startswith("Fire") == True)|(df[clasify].str.startswith("Utility") == True)|(df[clasify].str.startswith("Law Enforcement") == True)|(df[clasify].str.startswith("Structural") == True)]

EMOriginalRT[(EMOriginalRT['Incident Type'].str.startswith("Fire") == True)].groupby('Incident Type')

# %%
fireData = pd.read_csv("./../Data/FO.csv")

# %%
fireData # from 2011 til 2019
# Out:
#                                Incident Type Creation Date  Response Time
# 0                                Fire-School    2011-05-14            112
# 1                          Fire-Nursing Home    2011-05-25             70
# 2                    Fire-Sensitive Location    2011-06-27             86
# 3                              Fire-Hospital    2011-06-27             54
# 4                               Fire-Manhole    2011-07-11           1335
# 5                              Fire-Hospital    2011-07-21            189
# 6                             Fire-Explosion    2011-07-27           1234
# 7         Fire-10-77 (Residential High Rise)    2011-08-04             79
# 8                               Fire-Haz Mat    2011-08-08             83
# 9                               Fire-Manhole    2011-08-17            199
# 10                           Fire-Commercial    2011-08-19            106
# 11         Fire-10-76 (Commercial High Rise)    2011-08-28            236
# ...

# %%
fireData.groupby(['Incident Type']).agg(['count']).reset_index()
#42 types
#A lot of OTHERs (how many really do not fit in other category)
# Out:
#                               Incident Type Creation Date Response Time
#                                                     count         count
# 0    Fire-10-76 (Commercial High Rise Fire)            95            95
# 1         Fire-10-76 (Commercial High Rise)            31            31
# 2   Fire-10-77 (Residential High Rise Fire)            61            61
# 3        Fire-10-77 (Residential High Rise)            32            32
# 4                                Fire-Brush            11            11
# 5                  Fire-Building Evacuation             1             1
# 6                             Fire-Car Fire             1             1
# 7                             Fire-Collapse            35            35
# 8                           Fire-Commercial             8             8
# 9         Fire-Con Ed Feeder Cables on Fire             1             1
# 10                          Fire-Crane Fire             1             1
# ...

# %%
fireData.groupby(['Incident Type']).mean()
#Time response per category
# Out:
#                                          Response Time
# Incident Type
# Fire-10-76 (Commercial High Rise Fire)     1539.852632
# Fire-10-76 (Commercial High Rise)           253.193548
# Fire-10-77 (Residential High Rise Fire)    3919.311475
# Fire-10-77 (Residential High Rise)          875.875000
# Fire-Brush                                  348.090909
# Fire-Building Evacuation                     67.000000
# Fire-Car Fire                                21.000000
# Fire-Collapse                              4206.514286
# Fire-Commercial                             652.000000
# Fire-Con Ed Feeder Cables on Fire          4855.000000
# Fire-Crane Fire                            4709.000000
# Fire-Drill                                11489.000000
# Fire-Electrical                             444.000000
# Fire-Explosion                             6594.882353
# Fire-Fatal Elevator Incident                349.000000
# Fire-Fire in a Hotel                         47.000000
# ...

# %%
fireData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-10-76 (Commercial High Rise Fire)', :]
# Out:
#                               Incident Type Creation Date  Response Time
# 202  Fire-10-76 (Commercial High Rise Fire)    2014-05-14             31
# 209  Fire-10-76 (Commercial High Rise Fire)    2014-06-16             90
# 231  Fire-10-76 (Commercial High Rise Fire)    2014-08-21             94
# 242  Fire-10-76 (Commercial High Rise Fire)    2014-10-10             82
# 246  Fire-10-76 (Commercial High Rise Fire)    2014-11-02             67
# 254  Fire-10-76 (Commercial High Rise Fire)    2014-11-29            102
# 255  Fire-10-76 (Commercial High Rise Fire)    2014-12-09             40
# 259  Fire-10-76 (Commercial High Rise Fire)    2014-12-19             57
# 265  Fire-10-76 (Commercial High Rise Fire)    2015-01-25             53
# 266  Fire-10-76 (Commercial High Rise Fire)    2015-01-29         125006
# 281  Fire-10-76 (Commercial High Rise Fire)    2015-03-05             87
# 296  Fire-10-76 (Commercial High Rise Fire)    2015-04-11            140
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(fireData['Response Time'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-50b92edb3524> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(fireData['Response Time'])
#
# NameError: name 'fireData' is not defined

# %%
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-10-76 (Commercial High Rise)', :]['Response Time'], label='Fire-10-76 (Commercial High Rise)')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-10-77 (Residential High Rise)', :]['Response Time'], label='Fire-10-77 (Residential High Rise)')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Brush', :]['Response Time'], label='Fire-Brush')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Building Evacuation', :]['Response Time'], label='Fire-Building Evacuation')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Car Fire', :]['Response Time'], label='Fire-Car Fire')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Collapse', :]['Response Time'], label='Fire-Collapse')

plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Commercial', :]['Response Time'], label='Fire-Commercial')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Con Ed Feeder Cables on Fire', :]['Response Time'], label='Fire-Con Ed Feeder Cables on Fire')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Crane Fire', :]['Response Time'], label='Fire-Crane Fire')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Drill', :]['Response Time'], label='Fire-Drill')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Electrical', :]['Response Time'], label='Fire-Electrical')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Explosion', :]['Response Time'], label='Fire-Explosion')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Fatal Elevator Incident', :]['Response Time'], label='Fire-Fatal Elevator Incident')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Fire in a Hotel', :]['Response Time'], label='Fire-Fire in a Hotel')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Funeral Home', :]['Response Time'], label='Fire-Funeral Home')
plt.plot(emergencyData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-High Angle Rescue', :]['Response Time'], label='Fire-High Angle Rescue')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
plt.plot(fireData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-10-76 (Commercial High Rise Fire)', :]['Response Time'], label='Fire-10-76 (Commercial High Rise Fire)')

plt.plot(fireData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-10-77 (Residential High Rise Fire)', :]['Response Time'], label='Fire-10-77 (Residential High Rise Fire)')
plt.plot(fireData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Haz Mat', :]['Response Time'], label='Fire-Haz Mat')
plt.plot(fireData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-High Rise', :]['Response Time'], label='Fire-High Rise')

plt.plot(fireData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-School', :]['Response Time'], label='Fire-School')
plt.plot(fireData.loc[lambda df: emergencyData['Incident Type'] == 'Fire-Other', :]['Response Time'], label='Fire-Other')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Hospital', :]['Response Time'], label='Fire-Hospital')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-House of Worship - Synagogue', :]['Response Time'], label='Fire-House of Worship - Synagogue')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Manhole', :]['Response Time'], label='Fire-Manhole')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Metro North Train on Fire', :]['Response Time'], label='Fire-Metro North Train on Fire')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Nursing Home', :]['Response Time'], label='Fire-Nursing Home')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Overhead wires', :]['Response Time'], label='Fire-Overhead wires')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Overturn Tractor Trailer', :]['Response Time'], label='Fire-Overturn Tractor Trailer')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Residential', :]['Response Time'], label='Fire-Residential')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Sanitation Garage', :]['Response Time'], label='Fire-Sanitation Garage')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Sensitive Location', :]['Response Time'], label='Fire-Sensitive Location')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Smoke Condition', :]['Response Time'], label='Fire-Smoke Condition')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Transformer', :]['Response Time'], label='Fire-Transformer')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Transformer Fire', :]['Response Time'], label='Fire-Transformer Fire')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Transformer Inside Of Substation', :]['Response Time'], label='Fire-Transformer Inside Of Substation')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Truck Fire', :]['Response Time'], label='Fire-Truck Fire')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Turbine', :]['Response Time'], label='Fire-Turbine')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Vehicle Fire', :]['Response Time'], label='Fire-Vehicle Fire')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Vehicle Fire on the RFK Bridge', :]['Response Time'], label='Fire-Vehicle Fire on the RFK Bridge')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-Wires', :]['Response Time'], label='Fire-Wires')
plt.plot(fireData.loc[lambda df: fireData['Incident Type'] == 'Fire-arcing in electric panel', :]['Response Time'], label='Fire-arcing in electric panel')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
fireDataOriginal = pd.read_csv("./../dataprocess/c1.csv") #2077 events of FIRE
emergencyDataOriginal = pd.read_csv("./../dataprocess/Emergency_Response_Incidents.csv") #9018 events of EMERGENCY

# %%
emergencyDataOriginal.columns
# Out:
# Index(['Incident Type', 'Location', 'Borough', 'Creation Date', 'Closed Date',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
fireDataOriginal.groupby(['Incident Type']).agg(['count']).reset_index()
#51 types
# Out:
#                               Incident Type Unnamed: 0 Location Borough  \
#                                                  count    count   count
# 0    Fire-10-76 (Commercial High Rise Fire)         95       84      95
# 1         Fire-10-76 (Commercial High Rise)         31       31      31
# 2   Fire-10-77 (Residential High Rise Fire)         61       58      61
# 3        Fire-10-77 (Residential High Rise)         32       31      32
# 4                            Fire-1st Alarm        256      233     256
# 5                            Fire-2nd Alarm        683      651     683
# 6                            Fire-3rd Alarm        225      220     225
# 7                            Fire-4th Alarm         91       90      91
# 8                            Fire-5th Alarm         41       40      41
# 9                            Fire-6th Alarm         15       15      15
# 10                           Fire-7th Alarm          9        9       9
# ...

# %%
#Analyse min and max response time for each type
fireDataOriginal.groupby(['Incident Type']).agg({'Response Time' : [np.min, np.max]})
# Out:
#                                                       Response Time  \
#                                                                amin
# Incident Type
# Fire-10-76 (Commercial High Rise Fire)    0 days 00:07:30.000000000
# Fire-10-76 (Commercial High Rise)         0 days 00:15:14.000000000
# Fire-10-77 (Residential High Rise Fire)   0 days 00:04:24.000000000
# Fire-10-77 (Residential High Rise)        0 days 00:18:52.000000000
# Fire-1st Alarm                            0 days 00:03:16.000000000
# Fire-2nd Alarm                            0 days 00:00:00.000000000
# Fire-3rd Alarm                            0 days 00:03:34.000000000
# Fire-4th Alarm                            0 days 03:04:31.000000000
# Fire-5th Alarm                            0 days 03:46:30.000000000
# Fire-6th Alarm                           10 days 08:59:22.000000000
# Fire-7th Alarm                            0 days 07:43:01.000000000
# Fire-Brush                                0 days 00:29:08.000000000
# ...

# %%
emergencyDataOriginal.groupby(['Incident Type']).agg(['count']).reset_index()
# Out:
#                                          Incident Type Location Borough  \
#                                                           count   count
# 0                       Administration-1 PP Activation        1       2
# 1                 Administration-Con Ed Gas Assistance        1       1
# 2                                 Administration-Drill        9      14
# 3                     Administration-Equipment Failure        2       4
# 4                      Administration-Evacuation Drill        5       5
# 5                          Administration-IPAWS Outage        0       2
# 6                           Administration-Injured CIC        1       1
# 7                               Administration-Meeting        6       7
# 8                            Administration-Mutual Aid        0       2
# 9                       Administration-NYPD Assistance        1       1
# 10    Administration-New Year's Eve Times Square Event        1       1
# ...

# %%
emergencyDataOriginal[emergencyDataOriginal['Incident Type'].str.contains("Law")].groupby(['Incident Type']).agg(['count']).reset_index()
# Out:
#                                    Incident Type Location Borough  \
#                                                     count   count
# 0                   Law Enforcement-Civil Unrest        1       1
# 1                         Law Enforcement-Device       79      82
# 2                      Law Enforcement-Explosion       23      24
# 3                        Law Enforcement-Haz Mat       32      38
# 4                   Law Enforcement-Mobilization        7       9
# 5                          Law Enforcement-Other      119     144
# 6             Law Enforcement-Suspicious Package      356     406
# 7                     LawEnforcement-Bomb Threat        4       4
# 8                    LawEnforcement-Civil Unrest        0       1
# 9                          LawEnforcement-Device       24      24
# 10                      LawEnforcement-Explosion        3       3
# 11               LawEnforcement-Found Explosives        1       1
# ...

# %%
emergencyDataOriginal.groupby(['Incident Type']).agg({'Creation Date' : [np.min, np.max]})
# Out:
#                                                              Creation Date  \
#                                                                       amin
# Incident Type
# Administration-1 PP Activation                      06/12/2014 05:46:01 PM
# Administration-Con Ed Gas Assistance                07/07/2011 07:59:00 AM
# Administration-Drill                                02/23/2017 02:55:01 PM
# Administration-Equipment Failure                    05/05/2018 08:37:57 PM
# Administration-Evacuation Drill                     05/10/2011 08:17:30 AM
# Administration-IPAWS Outage                         01/22/2018 10:27:51 PM
# Administration-Injured CIC                          09/25/2013 07:24:25 AM
# Administration-Meeting                              03/16/2015 03:30:26 PM
# Administration-Mutual Aid                           02/08/2015 03:41:07 PM
# Administration-NYPD Assistance                      10/20/2011 08:57:36 AM
# ...

# %%
dfE = pd.read_csv("/home/gissemari/Documents/Research/emergency_model_running/emergency_model/Results/lstm/FO/logFO.csv")
#Column	Input_dim	x-y	Type	LearningRate	hiddenLayer	Epochs	NumLayers	RandomSamp	RMSE	Rel0	Rel1
dfE.columns
dfE.groupby(['x+AC0-y','Type','LearningRate','hiddenLayer','Epochs','NumLayers','RMSE']).agg(['mean']).reset_index()
# Out:
#      x+AC0-y                            Type LearningRate hiddenLayer Epochs  \
#
# 0   14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001          50  10000
# 1   14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001          50  20000
# 2   14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001          50  30000
# 3   14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001          50  30000
# 4   14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001          50  30000
# 5   14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001          50  30000
# 6   14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001          50  30000
# 7   14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001         100  30000
# 8   14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001         100  30000
# 9   14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001         100  30000
# 10  14+AF8-7  FO+AF8-0+AC0-14400+AF8-allTime       0.0001         100  30000
# ...

# %%
dfRNNE = pd.read_csv("./../Results/rnn/FO/LogResultsFOLAfol.csv")
dfRNNE.columns
dfRNNE.groupby(['x+AC0-y','Type','LearningRate','hiddenLayer','Epochs','NumLayers','RMSE']).agg(['mean']).reset_index()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-87d17aa4f40e> in <module>
# ----> 1 dfRNNE = pd.read_csv("./../Results/rnn/FO/LogResultsFOLAfol.csv")
#       2 dfRNNE.columns
#       3 dfRNNE.groupby(['x+AC0-y','Type','LearningRate','hiddenLayer','Epochs','NumLayers','RMSE']).agg(['mean']).reset_index()
#
# ...

# %%
FO = pd.read_csv("./../Data/FO_0-14400_allTime.csv", encoding = 'utf7')

# %%
FO.describe()
# Out:
#        Response Time
# count    1971.000000
# mean      904.222222
# std      2095.384827
# min         0.000000
# 25%        97.000000
# 50%       181.000000
# 75%       529.000000
# max     14365.000000

# %%
#FO.hist().show()
FO_filt = FO[FO['Response Time']<1440]# .count()#125

# %%
FO_filt
# Out:
#                                 Incident Type Creation Date  Response Time
# 1                              Fire-2nd Alarm    2011-05-04           1145
# 4                                 Fire-School    2011-05-14            112
# 6                              Fire-1st Alarm    2011-05-19             65
# 7                           Fire-Nursing Home    2011-05-25             70
# 8                              Fire-3rd Alarm    2011-05-26            272
# 9                              Fire-1st Alarm    2011-06-09             45
# 10                             Fire-1st Alarm    2011-06-11             66
# 11                             Fire-2nd Alarm    2011-06-24             90
# 12                             Fire-3rd Alarm    2011-06-25            339
# 13                    Fire-Sensitive Location    2011-06-27             86
# 14                              Fire-Hospital    2011-06-27             54
# ...

# %%
plt.plot(FO_filt['Response Time'][1000:1150])

# %%
FO_filt.hist().show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-853d42cff7e4> in <module>
# ----> 1 FO_filt.hist().show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
FO_filt1440 = FO[FO['Response Time']<1440]
FO_filt1440['Year'] = pd.to_datetime(FO_filt1440["Creation Date"]).dt.year

FO_filt720 = FO[FO['Response Time']<720]
FO_filt720['Year'] = pd.to_datetime(FO_filt720["Creation Date"]).dt.year


FO_filt4000 = FO[FO['Response Time']<4000]
FO_filt4000['Year'] = pd.to_datetime(FO_filt4000["Creation Date"]).dt.year
#fo_year = FO.groupby(['Incident Type']).agg(['mean','std','min','max','count']).reset_index()
#Total vs <4000
fo_year[fo_year==2011].count()#86 vs 79
fo_year[fo_year==2012].count()#135 vs 125
fo_year[fo_year==2013].count()#160 vs 149
fo_year[fo_year==2014].count()#215 vs 201
fo_year[fo_year==2015].count()#316 vs 306
fo_year[fo_year==2016].count()#250 vs 227
fo_year[fo_year==2017].count()#270 vs 258
fo_year[fo_year==2018].count()#290 vs 266
fo_year[fo_year==2019].count()#249 vs235
# Out:
# /home/gbejarano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/gbejarano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 235

# %%
# Out:
# /home/gbejarano/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
FO_filt4000.groupby(['Year']).agg(['mean','std','min','max','count']).reset_index()
FO_filt1440.groupby(['Year']).agg(['mean','std','min','max','count']).reset_index()
FO_filt720.groupby(['Year']).agg(['mean','std','min','max','count']).reset_index()
# Out:
#    Year Response Time
#                  mean         std min  max count
# 0  2011    139.828125  121.382062   3  650    64
# 1  2012    182.343434  141.564232  29  658    99
# 2  2013    181.600000  154.822121   0  649   120
# 3  2014    186.053254  150.040640   0  719   169
# 4  2015    184.488636  146.564096   0  708   264
# 5  2016    166.803109  142.716877   4  710   193
# 6  2017    164.840183  125.206607   0  702   219
# 7  2018    198.730088  146.727117   1  707   226
# 8  2019    206.435897  149.694809   4  719   195

# %%
plt.hist(FO_filt720['Response Time'])
plt.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-20441ed9a760> in <module>
#       1 plt.hist(FO_filt720['Response Time'])
# ----> 2 plt.clear()
#       3 plt.plot(FO_filt720['Response Time'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'clear'

# %%
plt.plot(FO_filt720['Response Time'][1000:1300])

# %%
FO_filt4000[FO_filt4000["Year"]==2019].groupby(['Incident Type']).agg(['mean','std','min','max','count']).reset_index()
#2011: 1st and 2nd alarm 21-19 still std>> mean
#2012: 1st - 4th alarm, for 3 std>>mean, 3rd 1114>863
#2013: 1st 6 4th alarm, for 3 std>>mean, 4th 1065>989
#2014: 1st - 4th alarm, for 3 std>>mean, 3rd 1114>863 and Fire-10-76 , Fire-Haz Mat, Fire-School
#2015: 1st - 4th alarm, for 3 std>>mean, 4th 1689>1179 and Fire-10-76 , Fire-Brush, Fire-Explosion, Fire-School
#2016: 1st - 4th alarm, for 3 std>>mean, 4th 616>345 and 5th, Fire-10-76, 77, Fire-Brush, Fire-School, Fire-ExplosionFire-Sensitive Location
#2017: 1st - 4th alarm, for 3 std>>mean, 4th 616>345 and 5th and 5 more
#2018: 1st - 4th alarm, for 3 std>>mean, 4th 1775>1382 and 5th and 5 more
#2018: 1st - 4th alarm, for 3 std>>mean, 4th 753>703 and 5th and 2 more
# Out:
#                               Incident Type Response Time                    \
#                                                      mean          std  min
# 0    Fire-10-76 (Commercial High Rise Fire)    314.360000   379.937591   44
# 1   Fire-10-77 (Residential High Rise Fire)    153.714286   213.802646   32
# 2                            Fire-1st Alarm    302.636364   325.271048   31
# 3                            Fire-2nd Alarm    415.489362   619.901323    6
# 4                            Fire-3rd Alarm    791.136364   960.879275    8
# 5                            Fire-4th Alarm    753.142857   703.531195  208
# 6                            Fire-5th Alarm   1042.500000   719.127596  534
# 7                             Fire-Collapse   1100.000000  1341.933307   68
# 8                            Fire-Explosion    938.666667  1297.174365  156
# 9                              Fire-Haz Mat    275.555556   346.015936    4
# ...

# %%
LA = pd.read_csv("./../Data/LA_0-14400_allTime.csv")
LA.describe()
# Out:
#        Response Time
# count     891.000000
# mean      652.932660
# std      2220.742618
# min         0.000000
# 25%        39.000000
# 50%        62.000000
# 75%       108.000000
# max     14308.000000

# %%
LA_filt = LA[LA['Response Time']<600]
LA_filt.hist().show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-37c70496a1b7> in <module>
#       1 LA_filt = LA[LA['Response Time']<600]
# ----> 2 LA_filt.hist().show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
LA['Law Enforcement-Suspicious Package'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-31a94f6c4720> in <module>()
# ----> 1 LA['Law Enforcement-Suspicious Package'].describe()
#
# /home/gissemari/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /home/gissemari/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
# ...

# %%
ut = pd.read_csv("/home/gissemari/Documents/Research/emergency_model_running/emergency_model/Data/utility.csv")
ut.describe()
# Out:
#        Response Time
# count    1412.000000
# mean      988.751416
# std      1692.725813
# min         0.000000
# 25%       125.750000
# 50%       422.000000
# 75%      1092.500000
# max     14352.000000

# %%
ut
# Out:
#                                           Incident Type Creation Date  \
# 0                              Utility-Transformer Fire    2011-05-04
# 1                         Utility-Electric Feeder Cable    2011-05-04
# 2                              Utility-Gas Line Rupture    2011-05-06
# 3                            Utility-Water Service Line    2011-05-09
# 4                                    Utility-Water Main    2011-05-13
# 5                              Utility-Gas Main Rupture    2011-05-13
# 6                              Utility-Gas Main Rupture    2011-05-24
# 7                                  Utility-Power Outage    2011-06-01
# 8                              Utility-Gas Main Rupture    2011-06-02
# 9                              Utility-Gas Main Rupture    2011-06-03
# 10                               Utility-Gas Main Break    2011-06-06
# 11                                 Utility-Power Outage    2011-06-09
# ...

# %%
ut.hist().show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-fe0e4219aec2> in <module>()
# ----> 1 ut.hist().show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
struc = pd.read_csv("/home/gissemari/Documents/Research/emergency_model_running/emergency_model/Data/structural.csv")
struc.describe()
# Out:
#        Response Time
# count    1092.000000
# mean     1076.251832
# std      2209.009602
# min         0.000000
# 25%       108.750000
# 50%       232.000000
# 75%       852.250000
# max     14351.000000

# %%
struc.hist().show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-7e1d95e9ebc9> in <module>()
# ----> 1 struc.hist().show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
strucFil = pd.read_csv("./../Data/With_Features/structural.csv")
strucFil.groupby(['Incident Type']).agg(['mean','std','min','max','count']).reset_index()
#All of them have std greater than mean
# Out:
#                         Incident Type Response Time                         \
#                                                mean          std min   max
# 0                   Structural-Bricks    894.440000   967.282365  19  3028
# 1                 Structural-Collapse    703.361905   919.180447   2  3975
# 2           Structural-Confined Space    195.821429   305.954494   0  1368
# 3    Structural-Construction Accident    221.158416   430.985632   6  2439
# 4                    Structural-Crane    789.192308  1094.743185  21  3791
# 5           Structural-Falling Debris    527.107692   778.837096  14  3945
# 6   Structural-Life Safety Violations    589.297872   754.014240   9  2990
# 7                    Structural-Other    421.568627   582.208556   7  3963
# 8         Structural-Partial Collapse    663.652174   856.872113   3  3378
# 9                 Structural-Scaffold    317.768000   380.004566  17  2255
# ...

# %%
stastStruct.columns
strucFil.sort_values(by=[[1,1]])#['Response Time'],['count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-a96b3cddcd99> in <module>
#       1 stastStruct.columns
# ----> 2 strucFil.sort_values(by=[[1,1]])#['Response Time'],['count']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: [1, 1]

# %%
utilFil = pd.read_csv("./../Data/With_Features/utility.csv")
utilFil.groupby(['Incident Type']).agg(['mean','std','min','max','count']).reset_index()
#All of them have std greater than mean
# Out:
#                    Incident Type Response Time                               \
#                                           mean          std min   max count
# 0  Utility-Electric Feeder Cable   1434.750000  1201.231673   8  3392    16
# 1      Utility-Gas High Pressure    466.425000   634.546081   2  3380    80
# 2       Utility-Gas Main Rupture    337.111111   544.060092   9  3633    54
# 3       Utility-Gas Service Line    326.440000   564.963685   0  2714    50
# 4                Utility-Manhole    574.051282   602.786428   0  2627    78
# 5                  Utility-Other    636.382550   785.586505   0  3830   149
# 6           Utility-Power Outage    414.015564   557.145571  12  3666   257
# 7             Utility-Water Main    987.364090   884.262994   6  3993   401
# 8     Utility-Water Service Line    758.280702   791.488879   7  3897   114
#
#   Incident Number
#              mean  std min max count
# 0               1  0.0   1   1    16
# 1               8  0.0   8   8    80
# ...

# %%
lawFil = pd.read_csv("./../Data/With_Features/law.csv")
lawFil.groupby(['Incident Type']).agg(['mean','std','min','max','count']).reset_index()
#All of them have std greater than mean
# Out:
#                         Incident Type Response Time                        \
#                                                mean         std min   max
# 0              Law Enforcement-Device     89.009615  108.975859  15   745
# 1             Law Enforcement-Haz Mat    198.260870  279.352859  17  1241
# 2               Law Enforcement-Other    298.044444  528.572126  13  3078
# 3  Law Enforcement-Suspicious Package    104.141115  246.160958   0  3090
#
#         Incident Number
#   count            mean  std min max count
# 0   104               2  0.0   2   2   104
# 1    23               3  0.0   3   3    23
# 2    90               4  0.0   4   4    90
# 3   574               1  0.0   1   1   574

# %%
fireFil = pd.read_csv("./../Data/With_Features/fire.csv")
fireFil.groupby(['Incident Type']).agg(['mean','std','min','max','count']).reset_index()
#All of them have std greater than mean except:
#Fire-4th Alarm and Fire-5th Alarm
# Out:
#                               Incident Type Response Time                    \
#                                                      mean          std  min
# 0    Fire-10-76 (Commercial High Rise Fire)    181.935484   246.990354    7
# 1         Fire-10-76 (Commercial High Rise)    253.193548   444.273446   15
# 2   Fire-10-77 (Residential High Rise Fire)    322.793103   609.157911    4
# 3        Fire-10-77 (Residential High Rise)    279.806452   581.970069   18
# 4                            Fire-1st Alarm    283.563559   527.997969    3
# 5                            Fire-2nd Alarm    379.833333   577.252899    0
# 6                            Fire-3rd Alarm    800.781421   887.761010    3
# 7                            Fire-4th Alarm   1180.666667   982.343941  184
# 8                            Fire-5th Alarm   1954.764706  1275.243091  226
# 9                             Fire-Collapse    526.785714   702.926283   20
# ...

# %%
fireFil[fireFil['Incident Type']=='Fire-2nd Alarm'].hist()
fireFil[fireFil['Incident Type']=='Fire-1st Alarm'].hist()
fireFil[fireFil['Incident Type']=='Fire-5th Alarm'].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a3aad4c50>,
# ...
#       dtype=object)

# %%
lawFil[lawFil['Incident Type']=='Law Enforcement-Suspicious Package'].hist()
lawFil[lawFil['Incident Type']=='Law Enforcement-Device'].hist()
lawFil[lawFil['Incident Type']=='Law Enforcement-Haz Mat'].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a3b08e9e8>,
# ...
#       dtype=object)

# %%
utilFil[utilFil['Incident Type']=='Utility-Water Main'].hist()
utilFil[utilFil['Incident Type']=='Utility-Power Outage'].hist()
utilFil[utilFil['Incident Type']=='Utility-Electric Feeder Cable'].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a3a750828>,
# ...
#       dtype=object)

# %%
strucFil[strucFil['Incident Type']=='Structural-Scaffold'].hist()
strucFil[strucFil['Incident Type']=='Structural-Collapse'].hist()
strucFil[strucFil['Incident Type']=='Structural-Bricks'].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a3a4f1400>,
# ...
#       dtype=object)
